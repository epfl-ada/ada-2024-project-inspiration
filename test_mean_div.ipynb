# %%
# Some basic imports
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
from statsmodels.stats import diagnostic
from scipy import stats
import networkx as nx
import statsmodels.api as sm
import statsmodels.formula.api as smf
import plotly.express as px
import plotly.io as pio
import plotly.graph_objects as go
import sys
import warnings
# warnings.filterwarnings('ignore')
import ast
import re

# %%
# Import some python modules
import src.data.cleaning_data as cleandata
import src.data.diversity as diversity_calc
import src.data.success as success
import src.data.data_exploration as data_explore
from src.data.data_exploration import color_palette

# %%
success_diversity_df = pd.read_csv('data/processed_data/success_and_diversity.csv')

# %%
success_diversity_df.head()
# Out:
#                 Movie_name  Movie_release_date  Ratings  Wikipedia_movie_ID  \
# 0                  'R Xmas                2001      5.7            24799628
# 1       'Til There Was You                1997      4.8            17841580
# 2       'Til We Meet Again                1940      6.7            16038391
# 3           'night, Mother                1986      7.6             8098268
# 4  *batteries not included                1987      6.6             3762449
#
#    Movie_box_office_revenue                   Movie_countries  \
# 0                       NaN  France, United States of America
# 1                 3525125.0          United States of America
# 2                       NaN          United States of America
# 3                       NaN          United States of America
# 4                65088797.0          United States of America
#
#                                      Movie_languages  Nomination  diversity  \
# 0                 English Language, Spanish Language       False   1.942695
# 1                                   English Language       False   0.360732
# 2  English Language, French Language, German Lang...       False   0.971348
# 3                                   English Language       False   0.180337
# 4                                   English Language       False   0.971348
#
#    Success  actor_number
# 0        0             4
# 1        0             5
# 2        0             2
# 3        1             2
# 4        1             2

# %%
colors_df = pd.DataFrame({
        'name': ['dark_red', 'darker_red', 'darkest_red',
                'blue', 'dark_blue', 'darker_blue', 'darker_blue2', 'darker_blue3', 'darkest_blue',
                'light_beige', 'light_beige2', 'light_yellow_beige',
                'beige', 'beige_plus', 'beige_plus_plus',
                'brown', 'dark_brown'],
        'hex': ['#A01812', '#7A0A08', '#3A0605',
                '#6CA9B3', '#3F6475', '#2A5563', '#204F61', '#284146', '#1A3040',
                '#FFF8D3', '#FEF7D0', '#FFF3BC',
                '#D8AC62', '#C48530', '#B77526',
                '#8A3D0C', '#4C1508']})
display(colors_df)
# Out:
#                   name      hex
# 0             dark_red  #A01812
# 1           darker_red  #7A0A08
# 2          darkest_red  #3A0605
# 3                 blue  #6CA9B3
# 4            dark_blue  #3F6475
# 5          darker_blue  #2A5563
# 6         darker_blue2  #204F61
# 7         darker_blue3  #284146
# 8         darkest_blue  #1A3040
# 9          light_beige  #FFF8D3
# 10        light_beige2  #FEF7D0
# 11  light_yellow_beige  #FFF3BC
# 12               beige  #D8AC62
# 13          beige_plus  #C48530
# 14     beige_plus_plus  #B77526
# 15               brown  #8A3D0C
# 16          dark_brown  #4C1508

# %%
data_explore.mean_diversity(success_diversity_df,ratings_quantile=0.75, box_office_quantile=0.75)
# Out:
# Average diversity for film successful: 0.9079
# Average diversity for film less successful: 0.8225
# Average diversity for film nominated: 0.8732
# Average diversity for film not nominated: 0.8447
# Average diversity for film with high ratings: 0.7936
# Average diversity for film with lower ratings: 0.8686
# Average diversity for film with high box office revenue: 1.1454
# Average diversity for film with lower box office revenue: 0.9831
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 data_explore.mean_diversity(success_diversity_df,)
#
# File c:\Users\franc\Documents\ada-2024-project-inspiration\src\data\data_exploration.py:282, in mean_diversity(df, ratings_quantile, box_office_quantile)
#     279 color_low = 'dark_red'
#     280 # Plot the bar plots for each criteria
#     281 # Plot overall success
# --> 282 plot_interactive_bar_plot(categories_success, diversity_success,
#     283                           'Success', color_palette(color_high), color_palette(color_low),
#     284                           'Average Diversity on overall Success', 'diversity_success')
#     285 # Plot nominations
#     286 plot_interactive_bar_plot(categories_nomination, diversity_nomination,
#     287                           'Nomination',color_palette(color_high), color_palette(color_low),
#     288                           'Average Diversity by Nomination', 'diversity_nomination')
#
# File c:\Users\franc\Documents\ada-2024-project-inspiration\src\data\data_exploration.py:189, in plot_interactive_bar_plot(categorie, diversity, name, color_high, color_low, title, html_output)
#     187 # Create the figure
#     188 fig = go.Figure()
# --> 189 colors = color_palette(color_high) + color_palette(color_low)
#     190 # Add the bar plot for high diversity
#     191 fig.add_trace(go.Bar(
#     192     x=categorie, y=diversity,
#     193     name=name,
#     194     marker=dict(color=colors)
#     195 ))
#
# File c:\Users\franc\Documents\ada-2024-project-inspiration\src\data\data_exploration.py:49, in color_palette(color)
#      36 colors_df = pd.DataFrame({
#      37     'name': ['dark_red', 'darker_red', 'darkest_red',
#      38             'blue', 'dark_blue', 'darker_blue', 'darker_blue2', 'darker_blue3', 'darkest_blue',
#    (...)
#      46             '#8A3D0C', '#4C1508']
#      47 })
#      48 # Return the hex code for the specified color
# ---> 49 color = colors_df[colors_df['name'] == color]['hex'].values[0]
#      50 return [color]
#
# File c:\Users\franc\anaconda3\envs\ada2024\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File c:\Users\franc\anaconda3\envs\ada2024\Lib\site-packages\pandas\core\arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# File c:\Users\franc\anaconda3\envs\ada2024\Lib\site-packages\pandas\core\series.py:6119, in Series._cmp_method(self, other, op)
#    6116 lvalues = self._values
#    6117 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 6119 res_values = ops.comparison_op(lvalues, rvalues, op)
#    6121 return self._construct_result(res_values, name=res_name)
#
# File c:\Users\franc\anaconda3\envs\ada2024\Lib\site-packages\pandas\core\ops\array_ops.py:321, in comparison_op(left, right, op)
#     316 if isinstance(rvalues, (np.ndarray, ABCExtensionArray)):
#     317     # TODO: make this treatment consistent across ops and classes.
#     318     #  We are not catching all listlikes here (e.g. frozenset, tuple)
#     319     #  The ambiguous case is object-dtype.  See GH#27803
#     320     if len(lvalues) != len(rvalues):
# --> 321         raise ValueError(
#     322             "Lengths must match to compare", lvalues.shape, rvalues.shape
#     323         )
#     325 if should_extension_dispatch(lvalues, rvalues) or (
#     326     (isinstance(rvalues, (Timedelta, BaseOffset, Timestamp)) or right is NaT)
#     327     and lvalues.dtype != object
#     328 ):
#     329     # Call the method on lvalues
#     330     res_values = op(lvalues, rvalues)
#
# ValueError: ('Lengths must match to compare', (17,), (1,))

# %%
color_palette("blue")
# concat 2 colors
colors = color_palette("blue") + color_palette("dark_red")
colors
# Out:
# ['#6CA9B3', '#A01812']
